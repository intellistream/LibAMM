# %%
if(!require('mldr.datasets')) {
    install.packages('mldr.datasets')
    library('mldr.datasets')
}

# %%
mediamill <- mediamill()  # Check and load the dataset
toBibtex(mediamill)
mediamill$measures
# Out:
# Looking for datasetmediamillin the download directory
#
#
# Now reading datasetmediamill
# [1] "@inproceedings{,\n  title = \"The challenge problem for automated detection of 101 semantic concepts in multimedia\",\n  author = \"Snoek, C. G. M. and Worring, M. and van Gemert, J. C. and Geusebroek, J. M. and Smeulders, A. W. M.\",\n  booktitle = \"Proc. 14th ACM International Conference on Multimedia, MULTIMEDIA06,\n  year = \"2006\",\n  pages = \"421--430\"\n}"
# $num.attributes
# [1] 221
#
# $num.instances
# [1] 43907
#
# $num.inputs
# [1] 120
#
# $num.labels
# [1] 101
#
# $num.labelsets
# [1] 6555
#
# $num.single.labelsets
# [1] 4104
#
# $max.frequency
# [1] 2363
#
# $cardinality
# [1] 4.375567
#
# $density
# [1] 0.04332244
#
# $meanIR
# [1] 256.4047
#
# $scumble
# [1] 0.354674
#
# $scumble.cv
# [1] 0.7425605
#
# $tcs
# [1] 18.1906

# %%
names(mediamill)
# Out:
# [1] "name"              "dataset"           "attributesIndexes"
# [4] "attributes"        "labels"            "labelsets"
# [7] "measures"          "bibtex"

# %%
class(mediamill$dataset)
# Out:
# [1] "data.frame"

# %%
summary(mediamill$dataset)
# Out:
#       Att1              Att2              Att3              Att4
#  Min.   :0.03066   Min.   :0.03806   Min.   :0.02719   Min.   :0.0400
#  1st Qu.:0.40586   1st Qu.:0.42849   1st Qu.:0.39868   1st Qu.:0.3255
#  Median :0.45229   Median :0.48096   Median :0.46768   Median :0.3759
#  Mean   :0.44136   Mean   :0.46176   Mean   :0.45032   Mean   :0.3717
#  3rd Qu.:0.49250   3rd Qu.:0.51582   3rd Qu.:0.52118   3rd Qu.:0.4216
#  Max.   :0.56868   Max.   :0.61017   Max.   :0.62028   Max.   :0.5726
#       Att5              Att6              Att7              Att8
#  Min.   :0.01547   Min.   :0.03576   Min.   :0.03559   Min.   :0.03201
#  1st Qu.:0.18333   1st Qu.:0.32523   1st Qu.:0.29526   1st Qu.:0.41652
#  Median :0.22409   Median :0.35856   Median :0.33575   Median :0.47504
#  Mean   :0.23217   Mean   :0.35529   Mean   :0.32703   Mean   :0.45575
#  3rd Qu.:0.27271   3rd Qu.:0.39335   3rd Qu.:0.36738   3rd Qu.:0.51588
# ...

# %%
write.csv(mediamill$dataset, "mediamill.csv", row.names = FALSE)
