# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
values = [7.1, 7.8, 7.5, 7, 7.4, 6.4, 5.6, 6.8, 5.9, 6.3, 6.7, 5.3, 6.1, 5, 4.9, 4.1, 4, 0.7, 5.5, 0.2, 4.5, -0.8, 2.4, -1.1, 0.9, -0.2, 1.8, 0, 6.2, -0.7, -0.1, 0.3, 1.2, -0.9, 2.2, 2.3, 4.4, 4.2, 6, -1, 1.3, -0.3, 2.7, 1.1, 1, 0.8, 6.5, 0.4, 7.2, 1.4, 5.2, 5.1, 4.7, 6.9, 3.1, -0.6, 1.9, 2.9, 6.6, 5.4, 1.6, 3.5, 0.6, 5.8, 0.5, 2.1, 3.3, 1.7, -1.2, 7.3, 0.1, 3.7, 2, 1.5, 2.5, 2.6, 3.4, 3.6, 2.8, 5.7, 4.3, 4.8, -0.5, 3, 3.2, 3.8, -0.4, 3.9, 4.6]

# %%
counts = [3, 1, 2, 11, 1, 12, 53, 13, 30, 26, 12, 90, 30, 164, 152, 533, 605, 18374, 64, 26717, 360, 152979, 5218, 13026, 16213, 41894, 11015, 31757, 30, 165628, 36454, 24937, 16134, 104244, 6869, 6129, 370, 498, 36, 26563, 15576, 46688, 3689, 16019, 16797, 17058, 23, 22127, 3, 14763, 87, 169, 288, 4, 2111, 120352, 9659, 2593, 13, 63, 12604, 1155, 19752, 35, 20477, 7546, 1651, 12087, 9779, 4, 29688, 868, 8583, 13665, 4954, 4249, 1397, 1103, 3219, 44, 405, 197, 70121, 2391, 1854, 735, 55145, 662, 301]

# %%
# Plot the histogram
plt.bar(values, counts)

# Customize the plot
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Value Distribution')
plt.grid(True)

# Show the plot
plt.show()
