# %%
import itertools as it
import os

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import LogLocator, LinearLocator

# OPT_FONT_NAME = 'Helvetica'
TICK_FONT_SIZE = 24
LABEL_FONT_SIZE = 28
LEGEND_FONT_SIZE = 30
LABEL_FP = FontProperties(style='normal', size=LABEL_FONT_SIZE)
LEGEND_FP = FontProperties(style='normal', size=LEGEND_FONT_SIZE)
TICK_FP = FontProperties(style='normal', size=TICK_FONT_SIZE)

MARKERS = (["", 'o', 's', 'v', "^", "", "h", "<", ">", "+", "d", "<", "|", "", "+", "_"])
# you may want to change the color map for different figures
COLOR_MAP = (
    '#FFFFFF', '#B03A2E', '#2874A6', '#239B56', '#7D3C98', '#00FFFF', '#F1C40F', '#F5CBA7', '#82E0AA', '#AEB6BF',
    '#AA4499', '#8B4513', '#FFD700', '#2E8B57', '#CD5C5C')
# you may want to change the patterns for different figures
PATTERNS = (
    ["", "////", "\\\\", "//", "o", "", "||", "-", "//", "\\", "o", "O", "////", ".", "|||", "o", "---", "+", "\\\\",
     "*"])

LABEL_WEIGHT = 'bold'
LINE_COLORS = COLOR_MAP
LINE_WIDTH = 3.0
MARKER_SIZE = 15.0
MARKER_FREQUENCY = 1000

matplotlib.rcParams['ps.useafm'] = True
matplotlib.rcParams['pdf.use14corefonts'] = True
matplotlib.rcParams['xtick.labelsize'] = TICK_FONT_SIZE
matplotlib.rcParams['ytick.labelsize'] = TICK_FONT_SIZE
# matplotlib.rcParams['font.family'] = OPT_FONT_NAME
matplotlib.rcParams['pdf.fonttype'] = 42


def DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend):
    # you may change the figure size on your own.
    fig = plt.figure(figsize=(40, 8))
    figure = fig.add_subplot(111)

    FIGURE_LABEL = legend_labels

    # values in the x_xis
    index = np.arange(len(x_values))
    # the bar width.
    # you may need to tune it to get the best figure.
    width = 0.05
    # draw the bars
    bars = [None] * (len(FIGURE_LABEL))
    for i in range(len(y_values)):
        bars[i] = plt.bar(index + i * width + width / 2,
                          y_values[i], width,
                          hatch=PATTERNS[i],
                          color=LINE_COLORS[i],
                          label=FIGURE_LABEL[i], edgecolor='black', linewidth=3)

    # sometimes you may not want to draw legends.
    if allow_legend == True:
        plt.legend(bars, FIGURE_LABEL,
                   prop=LEGEND_FP,
                   ncol=13,
                   loc='upper center',
                   #                     mode='expand',
                   shadow=False,
                   bbox_to_anchor=(0.5, 1.2), # horizontal, vertical
                   columnspacing=0.1,
                   handletextpad=0.2,
                   #                     bbox_transform=ax.transAxes,
                   #                     frameon=True,
                   #                     columnspacing=5.5,
                   #                     handlelength=2,
                   )

    # you may need to tune the xticks position to get the best figure.
    plt.xticks(index + 3 * 0.08, x_values, rotation=0)

    # plt.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    # plt.grid(axis='y', color='gray')
    # figure.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

    # you may need to tune the xticks position to get the best figure.
    # plt.yscale('log')
    #
    # plt.grid(axis='y', color='gray')
    figure.yaxis.set_major_locator(LinearLocator(10))
    # figure.xaxis.set_major_locator(LinearLocator(5))
    figure.get_xaxis().set_tick_params(direction='in', pad=10)
    figure.get_yaxis().set_tick_params(direction='in', pad=10)

    plt.xlabel(x_label, fontproperties=LABEL_FP)
    plt.ylabel(y_label, fontproperties=LABEL_FP)

    plt.savefig(filename + ".pdf", bbox_inches='tight')

# Example input data
x_values = ['Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5']
y_values = [
    [200, 300, 400, 250, 150],  # Data for line 1
    [350, 420, 390, 380, 290],  # Data for line 2
    [180, 210, 270, 240, 200],  # Data for line 3
]
legend_labels = ['Line 1', 'Line 2', 'Line 3']  # Labels for each line
x_label = 'Categories'  # Label for x-axis
y_label = 'Values'  # Label for y-axis
y_min = 0  # Minimum value for y-axis
y_max = 500  # Maximum value for y-axis
filename = 'example_figure'  # Output file name (without extension)
allow_legend = True  # Whether to display the legend or not
DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend)

# %%
import itertools as it
import os

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import LogLocator, LinearLocator

# OPT_FONT_NAME = 'Helvetica'
TICK_FONT_SIZE = 24
LABEL_FONT_SIZE = 28
LEGEND_FONT_SIZE = 30
LABEL_FP = FontProperties(style='normal', size=LABEL_FONT_SIZE)
LEGEND_FP = FontProperties(style='normal', size=LEGEND_FONT_SIZE)
TICK_FP = FontProperties(style='normal', size=TICK_FONT_SIZE)

MARKERS = (["", 'o', 's', 'v', "^", "", "h", "<", ">", "+", "d", "<", "|", "", "+", "_"])
# you may want to change the color map for different figures
COLOR_MAP = (
    '#FFFFFF', '#B03A2E', '#2874A6', '#239B56', '#7D3C98', '#00FFFF', '#F1C40F', '#F5CBA7', '#82E0AA', '#AEB6BF',
    '#AA4499', '#8B4513', '#FFD700', '#2E8B57', '#CD5C5C')
# you may want to change the patterns for different figures
PATTERNS = (
    ["", "////", "\\\\", "//", "o", "", "||", "-", "//", "\\", "o", "O", "////", ".", "|||", "o", "---", "+", "\\\\",
     "*"])

LABEL_WEIGHT = 'bold'
LINE_COLORS = COLOR_MAP
LINE_WIDTH = 3.0
MARKER_SIZE = 15.0
MARKER_FREQUENCY = 1000

matplotlib.rcParams['ps.useafm'] = True
matplotlib.rcParams['pdf.use14corefonts'] = True
matplotlib.rcParams['xtick.labelsize'] = TICK_FONT_SIZE
matplotlib.rcParams['ytick.labelsize'] = TICK_FONT_SIZE
# matplotlib.rcParams['font.family'] = OPT_FONT_NAME
matplotlib.rcParams['pdf.fonttype'] = 42


def DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend):
    # you may change the figure size on your own.
    fig = plt.figure(figsize=(40, 8))
    figure = fig.add_subplot(111)

    FIGURE_LABEL = legend_labels

    # values in the x_xis
    index = np.arange(len(x_values))
    # the bar width.
    # you may need to tune it to get the best figure.
    width = 0.05
    # draw the bars
    bars = [None] * (len(FIGURE_LABEL))
    for i in range(len(y_values)):
        bars[i] = plt.bar(index + i * width + width / 2,
                          y_values[i], width,
                          hatch=PATTERNS[i],
                          color=LINE_COLORS[i],
                          label=FIGURE_LABEL[i], edgecolor='black', linewidth=3)

    # sometimes you may not want to draw legends.
    if allow_legend == True:
        plt.legend(bars, FIGURE_LABEL,
                   prop=LEGEND_FP,
                   ncol=13,
                   loc='upper center',
                   #                     mode='expand',
                   shadow=False,
                   bbox_to_anchor=(0.5, 1.2), # horizontal, vertical
                   columnspacing=0.1,
                   handletextpad=0.2,
                   #                     bbox_transform=ax.transAxes,
                   #                     frameon=True,
                   #                     columnspacing=5.5,
                   #                     handlelength=2,
                   )

    # you may need to tune the xticks position to get the best figure.
    plt.xticks(index + 0.1 + 3 * 0.08, x_values, rotation=0)

    # plt.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    # plt.grid(axis='y', color='gray')
    # figure.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

    # you may need to tune the xticks position to get the best figure.
    # plt.yscale('log')
    #
    # plt.grid(axis='y', color='gray')
    figure.yaxis.set_major_locator(LinearLocator(10))
    # figure.xaxis.set_major_locator(LinearLocator(5))
    figure.get_xaxis().set_tick_params(direction='in', pad=10)
    figure.get_yaxis().set_tick_params(direction='in', pad=10)

    plt.xlabel(x_label, fontproperties=LABEL_FP)
    plt.ylabel(y_label, fontproperties=LABEL_FP)

    plt.savefig(filename + ".pdf", bbox_inches='tight')

# fro_error
x_values = ['PCA - amm(A^T, A)', 'CCA - amm(A^T, A)', 'CCA - amm(B^T, B)', 'CCA - amm(A^T, B)']
y_values = np.array([
    [0.      , 0.086872, 0.082991, 0.082297, 0.078311, 0.086994,
       0.084825, 0.081519, 0.078865, 0.022168, 0.027453, 1.058977,
       1.000001],
    [0.      , 0.05677 , 0.05677 , 0.053154, 0.054618, 0.057736,
       0.065839, 0.056432, 0.012763, 0.011123, 1.000151, 1.049398,
       1.      ],
    [0.      , 0.060801, 0.060801, 0.062052, 0.060656, 0.058222,
      0.062917, 0.066164, 0.017572, 0.01738 , 0.999824, 1.01781 ,
      1.      ],
    [0.      , 0.093813, 0.093813, 0.086443, 0.087891, 0.0916  ,
       0.09832 , 0.090137, 0.009423, 0.020635, 1.000414, 1.055314,
       1.      ]
]).T
legend_labels = ['mm', 'crs', 'weighted-cr', 'countSketch', 'tugOfWar', 'smp-pca', 'rip', 'fastjlt', 'cooFD', 'blockLRA', 'int8', 'pq-raw', 'vq']  # Labels for each line
x_label = ''  # Label for x-axis
y_label = 'Relative Fornolbious Error'  # Label for y-axis
y_min = 0  # Minimum value for y-axis
y_max = 500  # Maximum value for y-axis
filename = 'fro_error'  # Output file name (without extension)
allow_legend = True  # Whether to display the legend or not
DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend)

# %%
import itertools as it
import os

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import LogLocator, LinearLocator

# OPT_FONT_NAME = 'Helvetica'
TICK_FONT_SIZE = 24
LABEL_FONT_SIZE = 28
LEGEND_FONT_SIZE = 30
LABEL_FP = FontProperties(style='normal', size=LABEL_FONT_SIZE)
LEGEND_FP = FontProperties(style='normal', size=LEGEND_FONT_SIZE)
TICK_FP = FontProperties(style='normal', size=TICK_FONT_SIZE)

MARKERS = (["", 'o', 's', 'v', "^", "", "h", "<", ">", "+", "d", "<", "|", "", "+", "_"])
# you may want to change the color map for different figures
COLOR_MAP = (
    '#FFFFFF', '#B03A2E', '#2874A6', '#239B56', '#7D3C98', '#00FFFF', '#F1C40F', '#F5CBA7', '#82E0AA', '#AEB6BF',
    '#AA4499', '#8B4513', '#FFD700', '#2E8B57', '#CD5C5C')
# you may want to change the patterns for different figures
PATTERNS = (
    ["", "////", "\\\\", "//", "o", "", "||", "-", "//", "\\", "o", "O", "////", ".", "|||", "o", "---", "+", "\\\\",
     "*"])

LABEL_WEIGHT = 'bold'
LINE_COLORS = COLOR_MAP
LINE_WIDTH = 3.0
MARKER_SIZE = 15.0
MARKER_FREQUENCY = 1000

matplotlib.rcParams['ps.useafm'] = True
matplotlib.rcParams['pdf.use14corefonts'] = True
matplotlib.rcParams['xtick.labelsize'] = TICK_FONT_SIZE
matplotlib.rcParams['ytick.labelsize'] = TICK_FONT_SIZE
# matplotlib.rcParams['font.family'] = OPT_FONT_NAME
matplotlib.rcParams['pdf.fonttype'] = 42


def DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend):
    # you may change the figure size on your own.
    fig = plt.figure(figsize=(20, 8))
    figure = fig.add_subplot(111)

    FIGURE_LABEL = legend_labels

    # values in the x_xis
    index = np.arange(len(x_values))
    # the bar width.
    # you may need to tune it to get the best figure.
    width = 0.05
    # draw the bars
    bars = [None] * (len(FIGURE_LABEL))
    for i in range(len(y_values)):
        bars[i] = plt.bar(index + i * width + width / 2,
                          y_values[i], width,
                          hatch=PATTERNS[i],
                          color=LINE_COLORS[i],
                          label=FIGURE_LABEL[i], edgecolor='black', linewidth=3)

    # sometimes you may not want to draw legends.
    if allow_legend == True:
        plt.legend(bars, FIGURE_LABEL,
                   prop=LEGEND_FP,
                   ncol=13,
                   loc='upper center',
                   #                     mode='expand',
                   shadow=False,
                   bbox_to_anchor=(0.5, 1.2), # horizontal, vertical
                   columnspacing=0.1,
                   handletextpad=0.2,
                   #                     bbox_transform=ax.transAxes,
                   #                     frameon=True,
                   #                     columnspacing=5.5,
                   #                     handlelength=2,
                   )

    # you may need to tune the xticks position to get the best figure.
    plt.xticks(index + 0.1 + 3 * 0.08, x_values, rotation=0)

    # plt.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    # plt.grid(axis='y', color='gray')
    # figure.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

    # you may need to tune the xticks position to get the best figure.
    # plt.yscale('log')
    #
    # plt.grid(axis='y', color='gray')
    figure.yaxis.set_major_locator(LinearLocator(10))
    # figure.xaxis.set_major_locator(LinearLocator(5))
    figure.get_xaxis().set_tick_params(direction='in', pad=10)
    figure.get_yaxis().set_tick_params(direction='in', pad=10)

    plt.xlabel(x_label, fontproperties=LABEL_FP)
    plt.ylabel(y_label, fontproperties=LABEL_FP)

    plt.savefig(filename + ".pdf", bbox_inches='tight')

# end_to_end_error
x_values = ['PCA', 'CCA']
y_values = np.array([
    [0.070856, 0.071247, 0.071789, 0.07101 , 0.071883, 0.071159,
       0.071194, 0.071834, 0.070858, 0.070865, 0.070857, 1.901996,
       1.212048],
    [0.      , 0.23673 , 0.236607, 0.228632, 0.244066, 0.232047,
       0.232704, 0.230288, 0.895202, 0.048094, 1.      , 1.      ,
       1.      ]
]).T
legend_labels = ['mm', 'crs', 'weighted-cr', 'countSketch', 'tugOfWar', 'smp-pca', 'rip', 'fastjlt', 'cooFD', 'blockLRA', 'int8', 'pq-raw', 'vq']  # Labels for each line
x_label = ''  # Label for x-axis
y_label = 'Ending Error'  # Label for y-axis
y_min = 0  # Minimum value for y-axis
y_max = 500  # Maximum value for y-axis
filename = 'ending_error'  # Output file name (without extension)
allow_legend = False  # Whether to display the legend or not
DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend)

# %%
# latency
x_values = ['PCA', 'CCA']
y_values = np.array([
    [1.00000000e+00, 5.90823835e-01, 5.65087288e+01, 2.77222623e+01,
       2.20798586e+02, 3.37185111e+01, 8.45058450e+02, 7.77482184e+02,
       1.01186265e+02, 1.18697287e+03, 1.98788919e+02, 3.63709422e+01,
       1.99178330e+02], # MM 18467.753571
    [1.00000000e+00, 3.57446049e-01, 1.55440690e+02, 3.66838052e+00,
       1.66695295e+02, 3.18414384e+01, 2.87094129e+03, 3.88159894e+02,
       3.03891530e+01, 5.59830311e+03, 2.58404352e+02, 1.92363924e+01,
       7.48081245e+01] # MM 322.277515
]).T
legend_labels = ['mm', 'crs', 'weighted-cr', 'countSketch', 'tugOfWar', 'smp-pca', 'rip', 'fastjlt', 'cooFD', 'blockLRA', 'int8', 'pq-raw', 'vq']  # Labels for each line
x_label = ''  # Label for x-axis
y_label = 'Latency'  # Label for y-axis
y_min = 0  # Minimum value for y-axis
y_max = 500  # Maximum value for y-axis
filename = 'latency'  # Output file name (without extension)
allow_legend = False  # Whether to display the legend or not
DrawFigure(x_values, y_values, legend_labels, x_label, y_label, y_min, y_max, filename, allow_legend)
